# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\python310\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\python310\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)

# %%
import pandas

# %%
#importing excel file 
#data is taken from NBRM (National Bank of Republic of Macedonia) for the period of 30.03.20 to 30.03.23

usd_rates = pandas.read_excel("KursnaLista.xlsx")

# %%
#visualization of data by day groups

usd_rates.Middle.plot()
# Out:
# <Axes: >

# %%
# we are going to make a simple test to check if we are going to get right data
# first we are going to take two dates (past 7 days, future 7 days)
# we are going to take days from the past to check how the dollar rate changed 
# based on that we can predict how the rate is going to change in the future (for e.g. next 7 days)

past = 7
future = 7

# %%
money = usd_rates.Middle #get all rates

# %%
money #print to test if we are getting the right data
# Out:
# 0       56.2039
# 1       55.9135
# 2       56.3116
# 3       56.4146
# 4       56.5698
#          ...
# 1091    57.4174
# 1092    57.4174
# 1093    57.2682
# 1094    56.9090
# 1095    56.8775
# Name: Middle, Length: 1096, dtype: float64

# %%
# now we are going to take ssome random day
# let it be 100 day
# now we are going ot take past 7 days from 100 day and 7 future days from 100 day

money[100-past:100]
# Out:
# 93    55.0947
# 94    55.0848
# 95    54.6651
# 96    54.9670
# 97    54.9670
# 98    54.9670
# 99    54.4768
# Name: Middle, dtype: float64

# %%
# 7 future days
money[100:100+future]
# Out:
# 100    54.6457
# 101    54.6651
# 102    54.3952
# 103    54.7148
# 104    54.7148
# 105    54.7148
# 106    54.4576
# Name: Middle, dtype: float64

# %%
# now we have some data set on which our model is going to learn
# it will now the past (in our e.g. 7 days and knows the future next 7 days)
# we have data and our model based on this data is going to learn how the rate will go

# now we want to take some point to start making test
# we can't get very first value because we will not know the past
# we also can't get the latest value as we don't know the future

# how much data we have
len(money)
# Out:
# 1096

# %%
# taking data set
start = past
end = len(money) - future
print(f"We have {len(money)} values, and we will lok from {past} till {end} value")
# Out:
# We have 1096 values, and we will lok from 7 till 1089 value

# %%
table = []

# for each of those days we are going to take past and future
for i in range(start,end) :
    s = money[(i-past):(i+future)]
    table.append(list(s))

# %%
# preparing the data frame

past_columns = []
for i in range(past):
    past_columns.append(f"past_{i}")

    
future_columns = []
for i in range(future):
    future_columns.append(f"future_{i}")

# %%
# creating table
data_frame = pandas.DataFrame(data = table, columns = (past_columns + future_columns))

# %%
data_frame
# Out:
#        past_0   past_1   past_2   past_3   past_4   past_5   past_6  future_0  \
# 0     56.2039  55.9135  56.3116  56.4146  56.5698  57.2045  57.2045   57.2045
# 1     55.9135  56.3116  56.4146  56.5698  57.2045  57.2045  57.2045   57.1726
# 2     56.3116  56.4146  56.5698  57.2045  57.2045  57.2045  57.1726   56.6789
# 3     56.4146  56.5698  57.2045  57.2045  57.2045  57.1726  56.6789   56.7519
# 4     56.5698  57.2045  57.2045  57.2045  57.1726  56.6789  56.7519   56.7728
# ...       ...      ...      ...      ...      ...      ...      ...       ...
# 1077  58.2639  58.2639  57.6131  57.4506  58.4774  58.2204  58.0749   58.0749
# 1078   58.0749   57.5630   57.2513   57.2069   56.7103   57.4174   57.4174
# 1079   57.5630   57.2513   57.2069   56.7103   57.4174   57.4174   57.4174
# 1080   57.2513   57.2069   56.7103   57.4174   57.4174   57.4174   57.2682
# 1081   57.2069   56.7103   57.4174   57.4174   57.4174   57.2682   56.9090
#
# [1082 rows x 7 columns]

# %%
# now we are going to devide this sets of data
# we will hide some litle amount of data in order to check if the model is correct
# we will show this hidden data after all tests

X = data_frame[past_columns][:10]
Y = data_frame[future_columns][:10]

# %%
# hidden data

X_test = data_frame[past_columns][-10:] 
Y_test = data_frame[future_columns][-10:]

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\python310\lib\site-packages (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\python310\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\python310\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\python310\lib\site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression() #prepearing for learning
LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
prediction = LR.predict(X_test.head(1)) # checking how model is going to predict based on small amount of data
prediction
# Out:
# array([[69.27631523, 48.46681391, 53.31150516, 63.40487495, 53.36066977,
#         54.62198723, 53.79370661]])

# %%
Y_test.head(1) #checking what we except
# Out:
#       future_0  future_1  future_2  future_3  future_4  future_5  future_6
# 1072   57.6131   57.4506   58.4774   58.2204   58.0749   58.0749   58.0749

# %%
#visualizing data

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# %%
plt.plot(prediction[0], label = "Predicton")
plt.plot(Y_test.iloc[0], label = "Real")
plt.legend()

# %%
# now we are going to see the results for every of our test values

for i in range(10):
    err = mean_absolute_error(prediction[0], Y_test.iloc[i])
    print(f"date {i}, error = {err}")
    prediction = LR.predict([X_test.iloc[i]])
    plt.plot(prediction[0], label = "Predicton")
    plt.plot(Y_test.iloc[i], label = "Real")
    plt.legend()
    plt.show()
# Out:
# date 0, error = 6.20652964516749
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 1, error = 6.287372502310347
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 2, error = 2.5263529656167116
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 3, error = 4.98144564328233
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 4, error = 6.336730126861744
# date 5, error = 3.274667544419121
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 6, error = 5.480155261901428
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 7, error = 4.826254645757475
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 8, error = 5.778460507405491
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# date 9, error = 1.2192884964711368

# %%
# as this model does not give us correct values we are going to use new one

# %%
from sklearn.neighbors import KNeighborsRegressor #Метод ближайших соседей
KNN = KNeighborsRegressor()
KNN.fit(X,Y)
# Out:
# KNeighborsRegressor()

# %%
for i in range(10):
    err = mean_absolute_error(prediction[0], Y_test.iloc[i])
    print(f"date {i}, error = {err}")
    prediction = KNN.predict([X_test.iloc[i]])
    plt.plot(prediction[0], label = "Predicton")
    plt.plot(Y_test.iloc[i], label = "Real")
    plt.legend()
    plt.show()
# Out:
# date 0, error = 4.838484689358823
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 1, error = 1.50418857142857
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 2, error = 1.4757171428571436
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 3, error = 1.2958828571428538
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 4, error = 1.0784885714285701
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 5, error = 0.9845599999999989
# date 6, error = 0.8906314285714275
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 7, error = 0.7967028571428553
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 8, error = 0.7545885714285693
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 9, error = 0.7056885714285711
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(

# %%
# we can specify number of neighbours to get relevant data

KNN = KNeighborsRegressor(n_neighbors=1)
KNN.fit(X,Y)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
for i in range(10):
    err = mean_absolute_error(prediction[0], Y_test.iloc[i])
    print(f"date {i}, error = {err}")
    prediction = KNN.predict([X_test.iloc[i]])
    plt.plot(prediction[0], label = "Predicton")
    plt.plot(Y_test.iloc[i], label = "Real")
    plt.legend()
    plt.show()
# Out:
# date 0, error = 1.5130114285714262
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 1, error = 1.5434857142857143
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 2, error = 1.5150142857142856
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 3, error = 1.333514285714285
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 4, error = 1.1177857142857133
# date 5, error = 1.0238571428571421
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 6, error = 0.9299285714285708
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 7, error = 0.8359999999999995
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 8, error = 0.7782428571428568
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# date 9, error = 0.7293428571428565

# %%
# now we will try new model

from sklearn.neural_network import MLPRegressor # using neural network
#MLPR = MLPRegressor(hidden_layer_sizes=(256,128,64,32), max_iter=10000, random_state = 42)
MLPR = MLPRegressor(hidden_layer_sizes=(100,100,100,100), max_iter=20000) 
MLPR.fit(X,Y)
# Out:
# MLPRegressor(hidden_layer_sizes=(100, 100, 100, 100), max_iter=20000)

# %%
for i in range(10):
    err = mean_absolute_error(prediction[0], Y_test.iloc[i])
    print(f"date {i}, error = {err}")
    prediction = MLPR.predict([X_test.iloc[i]])
    plt.plot(prediction[0], label = "Predicton")
    plt.plot(Y_test.iloc[i], label = "Real")
    plt.legend()
    plt.show()
# Out:
# date 0, error = 0.42050054239869794
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 1, error = 0.3198248958147098
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 2, error = 0.3317381670753008
# date 3, error = 0.3438860427902597
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 4, error = 0.4726969391891984
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 5, error = 0.48750474742526756
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 6, error = 0.5474318457505406
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 7, error = 0.5202886461680853
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 8, error = 0.44658772849764816
# C:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# date 9, error = 0.5644202523061972
